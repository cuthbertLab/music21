# %%
import ipywidgets

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

# %%
@widgets.interact
def f(x=5):
    print(x)
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=15, min=-5), Output()), _dom_classes=('widget-in…

# %%
@widgets.interact(x=(0, 5))
def f(x=5):
    print(x)
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=5), Output()), _dom_classes=('widget-interact',)…

# %%
@widgets.interact_manual(
    color=['blue', 'red', 'green'], lw=(1., 10.))
def plot(freq=1., color='blue', lw=2, grid=True):
    t = np.linspace(-1., +1., 1000)
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            lw=lw, color=color)
    ax.grid(grid)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='freq', max=3.0, min=-1.0), Dropdown(description='col…

# %%
freq_slider = widgets.FloatSlider(
    value=2.,
    min=1.,
    max=10.0,
    step=0.1,
    description='Frequency:',
    readout_format='.1f',
)
freq_slider
# Out:
# FloatSlider(value=2.0, description='Frequency:', max=10.0, min=1.0, readout_format='.1f')

# %%
import ipywidgets as widgets
from traitlets import Unicode, Int, validate

# %%
class CounterWidget(widgets.DOMWidget):
    _view_name = Unicode('CounterView').tag(sync=True)
    _view_module = Unicode('counter').tag(sync=True)
    value = Int(0).tag(sync=True)

# %%
# %%javascript
# // We make sure the `counter` module is defined
# // only once.
# require.undef('counter');
#
# // We define the `counter` module depending on the
# // Jupyter widgets framework.
# define('counter', ["@jupyter-widgets/base"],
#        function(widgets) {
#
#     // We create the CounterView frontend class,
#     // deriving from DOMWidgetView.
#     var CounterView = widgets.DOMWidgetView.extend({
#
#         // This method creates the HTML widget.
#         render: function() {
#             // The value_changed() method should be
#             // called when the model's value changes
#             // on the kernel side.
#             this.value_changed();
#             this.model.on('change:value',
#                           this.value_changed, this);
#
#             var model = this.model;
#             var that = this;
#
#             // We create the plus and minus buttons.
#             this.bm = $('<button/>')
#             .text('-')
#             .click(function() {
#                 // When the button is clicked,
#                 // the model's value is updated.
#                 var x = model.get('value');
#                 model.set('value', x - 1);
#                 that.touch();
#             });
#
#             this.bp = $('<button/>')
#             .text('+')
#             .click(function() {
#                 var x = model.get('value');
#                 model.set('value', x + 1);
#                 that.touch();
#             });
#
#             // This element displays the current
#             // value of the counter.
#             this.span = $('<span />')
#             .text('0')
#             .css({marginLeft: '10px',
#                   marginRight: '10px'});
#
#             // this.el represents the widget's DOM
#             // element. We add the minus button,
#             // the span element, and the plus button.
#             $(this.el)
#             .append(this.bm)
#             .append(this.span)
#             .append(this.bp);
#         },
#
#         value_changed: function() {
#             // Update the displayed number when the
#             // counter's value changes.
#             var x = this.model.get('value');
#             $($(this.el).children()[1]).text(x);
#         },
#     });
#
#     return {
#         CounterView : CounterView
#     };
# });

# %%
w = CounterWidget()
w
# Out:
# CounterWidget()

# %%
def a_w(min=0, max=100):
    @widgets.interact(x=(min,max))
    def f(x=50):
        print(x)

# %%
a_w(20, 60)
# Out:
# interactive(children=(IntSlider(value=50, description='x', max=60, min=20), Output()), _dom_classes=('widget-i…

# %%
def a_w(min=0, max=100):
    @widgets.interact(x=(min,max))
    def f(x=(min+max)//2):
        print(x)

# %%
a_w(10, 20)
# Out:
# interactive(children=(IntSlider(value=15, description='x', max=20, min=10), Output()), _dom_classes=('widget-i…

# %%
from music21 import *
converter.subConverters.ConverterMusicXML
# Out:
# music21.converter.subConverters.ConverterMusicXML

# %%
corpus.parse('beethoven/opus133').show()

# %%
t = '/private/var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpphvf1gzb.png'
t
# Out:
# '/private/var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpphvf1gzb.png'

# %%
converter.subConverters.ConverterMusicXML.findNumberedPNGPath(t)
# Out:
# PosixPath('/private/var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpphvf1gzb-001.png')

# %%
corpus.parse('beach').show()

# %%
b = corpus.parse('bwv66.6')

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
b.show()

# %%
# %autoreload on

# %%
from music21 import *

# %%
b = corpus.parse('bwv66.6')

# %%
b.show()
# Out:
# /var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpm85ya2v5-1.png
# <class 'pathlib.PosixPath'>
# True
# /var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpm85ya2v5-1.png
# True
# /var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpm85ya2v5-1.png
# False

# %%
b.show('ipython.lily.png')
# Out:
# Changing working directory to: `/var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21'
# Processing `/var/folders/qg/klchy5t14bb2ty9pswk6c2bw0000gn/T/music21/tmpiauijifl.ly'
# Parsing...
# Interpreting music...[8]
# Preprocessing graphical objects...
# Calculating line breaks...
# Drawing systems...
# Layout output to `tmpiauijifl.ly.eps'...
# Converting to PNG...
# Deleting `tmpiauijifl.ly.eps'...
# Layout output to `tmpiauijifl.ly-1.eps'...
# Layout output to `tmpiauijifl.ly-2.eps'...
# Layout output to `tmpiauijifl.ly-3.eps'...
# Layout output to `tmpiauijifl.ly-4.eps'...
# Writing tmpiauijifl.ly-systems.texi...
# Writing tmpiauijifl.ly-systems.tex...
# Writing tmpiauijifl.ly-systems.count...
# Success: compilation successfully completed
# hi!

# %%
b.show()

# %%
beach = corpus.parse('beach')
beach.show()

# %%
clara = corpus.parse('schumann_clara')
clara.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 clara = corpus.parse('schumann_clara')
# ----> 2 clara.show()
#
# File ~/git/music21base/music21/stream/base.py:412, in Stream.show(self, fmt, app, **keywords)
#     410 if self.isSorted is False and self.autoSort:
#     411     self.sort()
# --> 412 return super().show(fmt=fmt, app=app, **keywords)
#
# File ~/git/music21base/music21/base.py:2959, in Music21Object.show(self, fmt, app, **keywords)
#    2957 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2958 formatWriter = scClass()
# -> 2959 return formatWriter.show(self,
#    2960                          regularizedConverterFormat,
#    2961                          app=app,
#    2962                          subformats=subformats,
#    2963                          **keywords)
#
# File ~/git/music21base/music21/converter/subConverters.py:474, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     470 else:
#     471     # multi-page png -- use our widget.
#     472     # noinspection PyPackageRequirements
#     473     from ipywidgets import interact  # type: ignore
# --> 474     last_number, num_digits = ConverterMusicXML.findPNGRange(fp, last_png)
#     475     stem = str(fp)[:fp.rfind('-')]
#     477     @interact(page=(1, last_number))
#     478     def page_display(page=1):
#
# File ~/git/music21base/music21/converter/subConverters.py:1035, in ConverterMusicXML.findPNGRange(firstFp, lastFp)
#    1033 suffix_len = 4  # len('.png')
#    1034 num_digits = len(inputFpStr) - dash_location - suffix_len
# -> 1035 last_number = int(str(lastFp)[dash_location:dash_location + num_digits])
#    1036 return (last_number, num_digits)
#
# ValueError: invalid literal for int() with base 10: 's/q'

# %%
beach.show()
# Out:
# interactive(children=(IntSlider(value=1, description='page', max=8, min=1), Output()), _dom_classes=('widget-i…
# <function music21.converter.subConverters.ConverterIPython.show.<locals>.page_display(page=1)>

# %%
clara.show()
# Out:
# interactive(children=(IntSlider(value=1, description='page', max=25, min=1), Output()), _dom_classes=('widget-…
# <function music21.converter.subConverters.ConverterIPython.show.<locals>.page_display(page=1)>

# %%
beach.show()
# Out:
# interactive(children=(IntSlider(value=1, description='page', max=8, min=1), Output()), _dom_classes=('widget-i…

# %%
clara.show()
# Out:
# interactive(children=(IntSlider(value=1, description='page', max=25, min=1), Output()), _dom_classes=('widget-…
# <function music21.converter.subConverters.ConverterIPython.show.<locals>.page_display(page=1)>
