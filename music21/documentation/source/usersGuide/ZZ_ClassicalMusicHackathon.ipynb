# %%
from music21 import *

# %%
c = corpus.parse('bwv66.6')
c.show()

# %%
c1 = c.chordify()

# %%
c1.show()

# %%
c.measures(0, 2).analyze('key')
# Out:
# <music21.key.Key of A major>

# %%
c.transpose('m3').parts[-1].show()

# %%
s = corpus.parse('schoenberg')

# %%
s.show()

# %%
for ch in s.recurse().getElementsByClass('Chord'):
    ch.lyric = ch.forteClass

# %%
s.show()
